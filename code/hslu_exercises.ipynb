# %%
# SET PATHS

# set the input data file location (where the file input_data.xlsx is stored)
input_path='C:/Users/boa/Documents/Repositories_Github/python-ehub/cases/hslu_exercises/input_data.xlsx'

# set the results location (where the results will be saved)
results_path = 'C:/Users/boa/Documents/Repositories_Github/python-ehub/results/hslu_exercises/'

# %%
# EXECUTE MODEL

# set the experiment name
experiment = 'experiment1'

from run_mod import *
from gen_plots2 import *

result_file = results_path + experiment + '/results.txt'
param_file = results_path + experiment + '/params.txt'

plot_path = results_path + experiment + '/'
if not os.path.exists(plot_path):
    os.makedirs(plot_path)

run_model(input_path, param_file, result_file) # defined in run_mod.py

generate_plots2(input_path, results_path, param_file, result_file, experiment) #defined in gen_plots.py
# Out:
# Generating model sets...
# Generating model variables...
# Generating model parameters...
# Generating model constraints...
# - System constraints
# - General technology constraints
# - Specific technology constraints
# - Network constraints
# - Storage constraints
# - Carbon constraints
# - Cost constraints
# Generating custom constraints/model specifications...
# Defining objective...
# Saving model parameter values to text file...
# Preprocessing...
# Running solver...
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\boa\AppData\Local\Temp\tmp7ojarov5.glpk.raw --wglp C:\Users\boa\AppData\Local\Temp\tmpn4vcevji.glpk.glp
#  --cpxlp C:\Users\boa\AppData\Local\Temp\tmph6pflmt1.pyomo.lp
# Reading problem data from 'C:\Users\boa\AppData\Local\Temp\tmph6pflmt1.pyomo.lp'...
# 350439 rows, 236541 columns, 911076 non-zeros
# 2198948 lines were read
# Writing problem data to 'C:\Users\boa\AppData\Local\Temp\tmpn4vcevji.glpk.glp'...
# 1726212 lines were written
# GLPK Simplex Optimizer, v4.65
# 350439 rows, 236541 columns, 911076 non-zeros
# Preprocessing...
# 171128 rows, 140167 columns, 421096 non-zeros
# Scaling...
#  A: min|aij| =  3.000e-03  max|aij| =  3.200e+00  ratio =  1.067e+03
# GM: min|aij| =  4.865e-01  max|aij| =  2.056e+00  ratio =  4.225e+00
# EQ: min|aij| =  2.451e-01  max|aij| =  1.000e+00  ratio =  4.079e+00
# Constructing initial basis...
# Size of triangular part is 171127
#       0: obj =  -1.626411743e+06 inf =   3.413e+13 (41747)
#     925: obj =  -1.544721098e+06 inf =   2.504e+13 (40513) 8
#    1788: obj =  -1.467686190e+06 inf =   1.870e+13 (39379) 8
#    2600: obj =  -1.394671753e+06 inf =   1.417e+13 (38323) 8
#    3494: obj =  -1.315405158e+06 inf =   1.049e+13 (37132) 9
#    4401: obj =  -1.230119429e+06 inf =   7.585e+12 (35843) 8
#    5286: obj =  -1.137592833e+06 inf =   5.333e+12 (34443) 9
#    6183: obj =  -1.041891191e+06 inf =   3.702e+12 (33004) 9
#    7064: obj =  -9.287443584e+05 inf =   2.401e+12 (31292) 9
#    7959: obj =  -8.169789769e+05 inf =   1.562e+12 (29610) 9
#    8850: obj =  -7.013999396e+05 inf =   9.980e+11 (27865) 8
#    9611: obj =  -6.017302330e+05 inf =   6.759e+11 (26365) 8
#   10444: obj =  -4.922817818e+05 inf =   4.382e+11 (24718) 8
#   11317: obj =  -3.823068808e+05 inf =   2.813e+11 (23073) 9
#   12225: obj =  -2.710077838e+05 inf =   1.776e+11 (21394) 9
#   13170: obj =  -1.684325323e+05 inf =   1.145e+11 (19899) 9
#   13984: obj =  -7.273569239e+04 inf =   7.478e+10 (18464) 8
#   14726: obj =   1.027788254e+04 inf =   5.070e+10 (17237) 7
#   15636: obj =   1.080141926e+05 inf =   3.111e+10 (15878) 9
#   16596: obj =   2.029749333e+05 inf =   1.848e+10 (14640) 8
#   17528: obj =   2.964888637e+05 inf =   1.034e+10 (13404) 9
#   18499: obj =   4.009848350e+05 inf =   4.751e+09 (12284) 8
#   19407: obj =   4.983167636e+05 inf =   1.822e+09 (11203) 7
#   20391: obj =   6.107752147e+05 inf =   2.844e+08 (10052) 8
#   21232: obj =   6.834689091e+05 inf =   2.326e+07 (9021) 7
#   22363: obj =   8.644957848e+05 inf =   1.873e+07 (7918) 2
#   23518: obj =   1.068925463e+06 inf =   1.590e+07 (6772)
#   24587: obj =   1.244905457e+06 inf =   1.345e+07 (5702) 1
#   25711: obj =   1.436532450e+06 inf =   1.078e+07 (4568)
#   26799: obj =   1.604095656e+06 inf =   8.471e+06 (3480)
#   27930: obj =   1.780576498e+06 inf =   6.039e+06 (2351)
#   29030: obj =   1.979840231e+06 inf =   3.292e+06 (1251)
#   30115: obj =   2.187522500e+06 inf =   4.294e+05 (167)
#   30290: obj =   2.218916590e+06 inf =   5.250e-11 (0)
# * 30551: obj =   2.218174463e+06 inf =   2.759e-11 (0) 3
# OPTIMAL LP SOLUTION FOUND
# Time used:   165.3 secs
# Memory used: 316.7 Mb (332098148 bytes)
# Writing basic solution to 'C:\Users\boa\AppData\Local\Temp\tmp7ojarov5.glpk.raw'...
# 586989 lines were written
# Saving results to text file...
#
# generating results plots
#
# FINISHED!
